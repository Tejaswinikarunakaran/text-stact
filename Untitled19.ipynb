# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Tejaswini.csv")
df.head()
# Out:
#    Rating                      Company Name          Job Title   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries Reported   Location
# 0                  3  Bangalore
# 1                  3  Bangalore
# 2                  3  Bangalore
# 3                  3  Bangalore
# 4                  3  Bangalore

# %%
df.shape
# Out:
# (22768, 6)

# %%
df.columns
# Out:
# Index(['Rating', 'Company Name', 'Job Title', 'Salary', 'Salaries Reported',
#        'Location'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22768 entries, 0 to 22767
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rating             22768 non-null  float64
#  1   Company Name       22767 non-null  object
#  2   Job Title          22768 non-null  object
#  3   Salary             22768 non-null  int64
#  4   Salaries Reported  22768 non-null  int64
#  5   Location           22768 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 1.0+ MB

# %%
df.describe()
# Out:
#              Rating        Salary  Salaries Reported
# count  22768.000000  2.276800e+04       22768.000000
# mean       3.918245  6.954191e+05           1.855850
# std        0.519692  8.844216e+05           6.823963
# min        1.000000  2.112000e+03           1.000000
# 25%        3.700000  3.000000e+05           1.000000
# 50%        3.900000  5.000000e+05           1.000000
# 75%        4.200000  9.000000e+05           1.000000
# max        5.000000  9.000000e+07         361.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Rating'].plot(kind='hist', bins=20, title='Rating')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Salary'].plot(kind='hist', bins=20, title='Salary')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
df.isnull().sum()
# Out:
# Rating               0
# Company Name         1
# Job Title            0
# Salary               0
# Salaries Reported    0
# Location             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Rating"].nunique()
# Out:
# 41

# %%
plt.xlabel('Salary') # It's better to label axes with the data they represent
plt.ylabel('Company') # Similarly, label the y-axis
plt.title('Salary vs Company')
plt.plot(df.index, df['Salary']) # Plot Salary against the DataFrame index

plt.show()

# %%
plt.xlabel('Salaries Reported')
plt.ylabel('Rating')
plt.title('Company vs Rating')

# Replace 'Company' with the correct column name from the print output if necessary
plt.plot(df.index, df['Salaries Reported'])
plt.show()

# %%
plt.xlabel('Salary')
plt.ylabel('Location')
plt.title('Salary vs Location ')

plt.plot(df.index, df['Salary'])
plt.show()

# %%
x = df.Location
y = df.Salary
print(x)
print(y)
# Out:
# 0        Bangalore
# 1        Bangalore
# 2        Bangalore
# 3        Bangalore
# 4        Bangalore
#            ...
# 22763    Bangalore
# 22764    Bangalore
# 22765    Bangalore
# 22766    Bangalore
# 22767    Bangalore
# Name: Location, Length: 22768, dtype: object
# 0         400000
# 1         400000
# 2        1000000
# 3         300000
# 4         600000
#           ...
# 22763     200000
# 22764     300000
# 22765     192000
# 22766     300000
# 22767     300000
# Name: Salary, Length: 22768, dtype: int64

# %%
plt.scatter(x, y, marker = 'o')
