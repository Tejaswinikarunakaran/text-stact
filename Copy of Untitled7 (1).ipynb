# %%
num1= complex(3,4)
num2= complex(5,6)
result= num1* num2
print(result)
# Out:
# (-9+38j)

# %%
print("Hello world!",end="")
print("This is a single line.")
# Out:
# Hello world!This is a single line.

# %%
def mult(x,y):
  return x*y
  num1=90
  num=32
  print(mult(num1,num2))

# %%
i=0
j=4
for r in range(7):
  for c in range(5):
    if c==0 or (r==c+2 and c>0):
      print("*",end="")
    elif((r==i and c==j)and c>0):
      print("*",end="")
      i=i+1
      j=j-1
    else:
        print(end="")
        i=i+1
        j=j-1
  else:
        print(end="")
        print()
# Out:
# *
# *
# *
# **
# **
# **
# **

# %%
num = int(input("Enter a number:"))

for i in range(1,11):
  print(num, 'x',i,'=',num*i)
# Out:
# Enter a number:5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
number=97.112 * 87.145
print(number)
# Out:
# 8462.825239999998

# %%
list1 = [50,90,70,56,98,45,32]
list2 = [2,3,6,8,5,1,9]
multiply = []
for number1,number2 in zip(list1, list2):
  multiply.append(number1* number2)
  print(multiply)
# Out:
# [100]
# [100, 270]
# [100, 270, 420]
# [100, 270, 420, 448]
# [100, 270, 420, 448, 490]
# [100, 270, 420, 448, 490, 45]
# [100, 270, 420, 448, 490, 45, 288]

# %%
import math
list1 = [40,60,75,34]
list2 =[4,6,1,9]
p1 = math.prod
