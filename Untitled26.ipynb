# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/software.csv")

# %%
df.head()
# Out:
#    Rating                      Company Name          Job Title   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries Reported   Location
# 0                  3  Bangalore
# 1                  3  Bangalore
# 2                  3  Bangalore
# 3                  3  Bangalore
# 4                  3  Bangalore

# %%
df.columns
# Out:
# Index(['Rating', 'Company Name', 'Job Title', 'Salary', 'Salaries Reported',
#        'Location'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
#scaled_features =scaler.fit_transform(df.drop('Salaries Reported',axis=1))
print(df.drop('Salaries Reported', axis=1).dtypes)
# Out:
# Rating          float64
# Company Name     object
# Job Title        object
# Salary            int64
# Location         object
# dtype: object

# %%
#scaled_features =scaler.fit_transform(df.drop('Salaries Reported',axis=1))

# %%
from IPython import get_ipython
from IPython.display import display
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/content/software.csv")

df.head()

df.columns

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# Calculate scaled_features by dropping the 'Salaries Reported' column
scaled_features =scaler.fit_transform(df.drop('Salaries',axis=1))
print(df.drop('Salaries Reported', axis=1).dtypes)

# Now that scaled_features is defined, create the new DataFrame
df_feat = pd.DataFrame(scaled_features,columns=df.columns[:-1])
df_feat.head()

# Remove these redundant commented blocks as they are not needed
# %%
#scaled_features =scaler.fit_transform(df.drop('Salaries Reported',axis=1))
# %%
# Uncomment the line to calculate scaled_features
# df_feat = pd.DataFrame(scaled_features,columns=df.columns[:-1])
# df_feat.head()
# %%
# Uncomment the line to calculate scaled_features
# scaled_features =scaler.fit_transform(df.drop('Rating',axis=1)) # U.ncommented this line
# df_feat = pd.DataFrame(scaled_features,columns=df.columns[:-1])
#
# df_feat.head()
# %%
# Uncomment the line to calculate scaled_features
# scaled_features =scaler.fit_transform(df.drop("Rating",axis=1)) # Uncommented this line
# df_feat = pd.DataFrame(scaled_features,columns=df.columns[:1])
# df_feat.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-3411049369> in <cell line: 0>()
#       6 import seaborn as sns
#       7
# ----> 8 df = pd.read_csv("/content/software.csv")
#       9
#      10 df.head()
#
# ...
