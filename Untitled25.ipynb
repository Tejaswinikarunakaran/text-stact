# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
# %matplotlib inline

# %%
df = pd.read_csv('/content/software.csv')
df
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22763     4.7                  Expert Solutions             Web Developer
# 22764     4.0           Nextgen Innovation Labs             Web Developer
# 22765     4.1                           Fresher  Full Stack Web Developer
# 22766     4.1                         Accenture  Full Stack Web Developer
# 22767     3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  Salaries Reported   Location
# ...

# %%
df.rename(columns={'Salary':'Salary', 'Rating':'Rating','Spending Score (1-100)':'score'}, inplace=True)

# %%
df
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22763     4.7                  Expert Solutions             Web Developer
# 22764     4.0           Nextgen Innovation Labs             Web Developer
# 22765     4.1                           Fresher  Full Stack Web Developer
# 22766     4.1                         Accenture  Full Stack Web Developer
# 22767     3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  Salaries Reported   Location
# ...

# %%
df.shape
# Out:
# (22768, 6)

# %%
seaborn.pairplot(df[['Location','Rating','Salary']])

# %%
x= df.drop(['Salary','Location'], axis = 1)
x
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22763     4.7                  Expert Solutions             Web Developer
# 22764     4.0           Nextgen Innovation Labs             Web Developer
# 22765     4.1                           Fresher  Full Stack Web Developer
# 22766     4.1                         Accenture  Full Stack Web Developer
# 22767     3.8                   Thomson Reuters   Associate Web Developer
#
#        Salaries Reported
# 0                      3
# 1                      3
# ...

# %%
y = df['Salary']
y
# Out:
# 0         400000
# 1         400000
# 2        1000000
# 3         300000
# 4         600000
#           ...
# 22763     200000
# 22764     300000
# 22765     192000
# 22766     300000
# 22767     300000
# Name: Salary, Length: 22768, dtype: int64

# %%
import sklearn.cluster as cluster

# %%
kmeans = cluster.KMeans(n_clusters = 5) # k = 5

# %%
kmeans = kmeans.fit(df[['Salary','Rating']])

# %%
kmeans.cluster_centers_
# Out:
# array([[7.06117736e+05, 3.91158005e+00],
#        [3.33238342e+06, 3.99326425e+00],
#        [9.00000000e+07, 3.60000000e+00],
#        [2.69465728e+05, 3.90855244e+00],
#        [1.46195501e+06, 3.94958217e+00]])

# %%
df['clusters'] = kmeans.labels_

# %%
df['clusters']
# Out:
# 0        3
# 1        3
# 2        0
# 3        3
# 4        0
#         ..
# 22763    3
# 22764    3
# 22765    3
# 22766    3
# 22767    3
# Name: clusters, Length: 22768, dtype: int32

# %%
df.head(100)
# Out:
#     Rating                      Company Name          Job Title   Salary  \
# 0      3.8                            Sasken  Android Developer   400000
# 1      4.5  Advanced Millennium Technologies  Android Developer   400000
# 2      4.0                         Unacademy  Android Developer  1000000
# 3      3.8                SnapBizz Cloudtech  Android Developer   300000
# 4      4.4            Appoids Tech Solutions  Android Developer   600000
# ..     ...                               ...                ...      ...
# 95     4.8                  Fermedicius Labs  Android Developer   200000
# 96     4.1                             Dunzo  Android Developer  2800000
# 97     3.7                          ABC Tech  Android Developer   852000
# 98     4.3             SpurTree Technologies  Android Developer   700000
# 99     4.0                      Grab (India)  Android Developer  1200000
#
#     Salaries Reported   Location  clusters
# 0                   3  Bangalore         3
# ...

# %%
df['clusters'].value_counts()
# Out:
# clusters
# 3    10459
# 0     8139
# 4     3590
# 1      579
# 2        1
# Name: count, dtype: int64

# %%
seaborn.scatterplot(x ='Salary', hue='Location', data=df)
# Out:
# <Axes: xlabel='Salary'>

# %%
from sklearn.cluster import KMeans
