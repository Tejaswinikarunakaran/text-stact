# %%
import pandas as pd
df = pd.read_csv(r"/content/software.csv")
df.head()
# Out:
#    Rating                      Company Name          Job Title   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries Reported   Location
# 0                  3  Bangalore
# 1                  3  Bangalore
# 2                  3  Bangalore
# 3                  3  Bangalore
# 4                  3  Bangalore

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style = 'darkgrid', rc = {'figure.figsize':(10,6)},font_scale = 1.5)
sns.distplot(df['Salary'])
# Out:
# <ipython-input-20-ba364f05183d>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Salary'])
# <Axes: xlabel='Salary', ylabel='Density'>

# %%
sns.distplot??

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style = 'darkgrid', rc = {'figure.figsize':(10,6)},font_scale = 1.5)
# Use the correct DataFrame 'df' instead of 'tips' to access the 'Salary' column
sns.distplot(df['Salary'])
# Out:
# <ipython-input-24-ab51c70f28f4>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Salary'])
# <Axes: xlabel='Salary', ylabel='Density'>

# %%
sns.distplot(df['Salary'], hist = False, vertical= True, color = 'red')
# Out:
# <ipython-input-25-7f4bffb29c64>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Salary'], hist = False, vertical= True, color = 'red')
# <Axes: xlabel='Density', ylabel='Salary'>

# %%
sns.distplot(df['Salary'], kde = False)
# Out:
# <ipython-input-28-762c0382f87f>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Salary'], kde = False)
# <Axes: xlabel='Salary'>

# %%
sns.distplot(df['Rating'], kde = False)
# Out:
# <ipython-input-31-d79ae44e6784>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Rating'], kde = False)
# <Axes: xlabel='Rating'>

# %%
sns.distplot(df['Salary'], hist = False, vertical= True, color = 'purple')
# Out:
# <ipython-input-32-0796547a7b71>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Salary'], hist = False, vertical= True, color = 'purple')
# <Axes: xlabel='Density', ylabel='Salary'>

# %%
sns.distplot(df['Rating'], hist = False, vertical= True, color = 'purple')
# Out:
# <ipython-input-33-9b805d12b51f>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Rating'], hist = False, vertical= True, color = 'purple')
# <Axes: xlabel='Density', ylabel='Rating'>

# %%
sns.distplot(df['Salary'], hist = False, vertical= True, color = 'purple')
# Out:
# <ipython-input-38-0796547a7b71>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Salary'], hist = False, vertical= True, color = 'purple')
# <Axes: xlabel='Density', ylabel='Salary'>

# %%
sns.jointplot(x = 'Salary', y = 'Location', data = df, kind = 'scatter')

# %%
sns.jointplot(x = 'Salary', y = 'Location', data = df, kind = 'kde')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-fb417c523a88> in <cell line: 0>()
# ----> 1 sns.jointplot(x = 'Salary', y = 'Location', data = df, kind = 'kde')
#
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2295         joint_kws.setdefault("color", color)
#    2296         joint_kws.setdefault("warn_singular", False)
# -> 2297         grid.plot_joint(kdeplot, **joint_kws)
#    2298
#    2299         marginal_kws.setdefault("color", color)
#
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py in plot_joint(self, func, **kwargs)
#    1830
#    1831         if str(func.__module__).startswith("seaborn"):
# -> 1832             func(x=self.x, y=self.y, **kwargs)
# ...
