# %%
a=5

# %%
print(a)
# Out:
# 5

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
a=1.2
b=2.4
print(type(a))
# Out:
# <class 'float'>

# %%
a="cat"
b="dog"
print(type(a))
# Out:
# <class 'str'>

# %%
a= bool(1)
print(a)
print(type(a))
# Out:
# True
# <class 'bool'>

# %%
Com= 3+5j
print(Com)
print(type(Com))
# Out:
# (3+5j)
# <class 'complex'>

# %%
n=(1,2,3,4,5)
print(type(n))
# Out:
# <class 'tuple'>

# %%
a=['a','b','c','d','e']
print(a)
print(type(a))
print(a[0])
print(a[4])
print(a[0:4])
# Out:
# ['a', 'b', 'c', 'd', 'e']
# <class 'list'>
# a
# e
# ['a', 'b', 'c', 'd']

# %%
a=[1,2,3,4,5]
print(a)
print(type(a))
print(a[0])
print(a[4])
print(a[0:4])
# Out:
# [1, 2, 3, 4, 5]
# <class 'list'>
# 1
# 5
# [1, 2, 3, 4]

# %%
s="tejaswini"
print(s[0:4])
# Out:
# teja

# %%
t="laptop"
print(t[-3:-1])
# Out:
# to

# %%
t="laptop"
print(t[-4:-2])
# Out:
# pt

# %%
set1={1,2,3}
set2={4,5,6}
set3=set1.union(set2)
print(set3)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
setA={0,1,2,3,4}
setB={2,3,4,5,6}
setC=setA.intersection(setB)
print(setC)
# Out:
# {2, 3, 4}
