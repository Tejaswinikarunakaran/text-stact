# %%
def mult(x,y):
  return x*y
  num1=90
  num2=89
  print(mult(num1,num2))

# %%
from os.path import defpath
a = 2
defpath
# Out:
# '/bin:/usr/bin'

# %%
a = 5
print(5)
# Out:
# 5

# %%
number=171*899
print("The product is",number)
# Out:
# The product is 153729

# %%
number=4*5
print("The product is",number)
# Out:
# The product is 20

# %%
number=6-10
print(number)
# Out:
# -4

# %%
number=124-678
print(number)
# Out:
# -554

# %%
number=8976%7
print(number)
# Out:
# 2

# %%
number=1000/10
print(number)
# Out:
# 100.0
